# %% [markdown]
# <a href="https://colab.research.google.com/github/ANNON17-byte/LLM-Tokenizer-/blob/main/LLM_Tokenizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("the-verdict.txt", "r", encoding="utf-8") as file:
    text_ver = file.read()

print("Total characters:", len(text_ver))
print(text_ver[:99])
# Out:
# Total characters: 25401
# ﻿The Verdict PDF
# Prannoy Roy
#
# Scan to Download
#
#
#
# The Verdict
# Decoding India's Election Dynamics an

# %%
# we use python's regular expression library for splitting text

import re

text = "Hello world, yoooo."
result = re.split(r'(\s)', text)

print(result)
# Out:
# ['Hello', ' ', 'world,', ' ', 'yoooo.']

# %%
# for removing whitespaces

result = [item for item in result if item.strip()]

print(result)
# Out:
# ['Hello', 'world,', 'yoooo.']

# %% [markdown]
# Removing whitespaces reduces the memory and computing
# requirements. However, keeping whitespaces can be useful if we train models that
# are sensitive to the exact structure of the text (for example, Python code, which is
# sensitive to indentation and spacing). Here, we remove whitespaces for simplicity
# and brevity of the tokenized outputs.

# %%
text = "Hello, world. Is this-- a test?"
result = re.split(r'([,.:;?_!"()\']|--|\s)', text)
result = [item for item in result if item.strip()]
print(result)
# Out:
# ['Hello', ',', 'world', '.', 'Is', 'this', '--', 'a', 'test', '?']

# %%
# for the verdict

preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', text_ver)
preprocessed = [item for item in preprocessed if item.strip()]
print(preprocessed[:30])
# Out:
# ['\ufeffThe', 'Verdict', 'PDF', 'Prannoy', 'Roy', 'Scan', 'to', 'Download', 'The', 'Verdict', 'Decoding', 'India', "'", 's', 'Election', 'Dynamics', 'and', 'Voter', 'Choices', 'Written', 'by', 'Bookey', 'Check', 'more', 'about', 'The', 'Verdict', 'Summary', 'Listen', 'The']

# %%
print(len(preprocessed))
# Out:
# 4101

# %% [markdown]
# Let's implement a complete tokenizer class in Python.
#
# The class will have an encode method that splits
# text into tokens and carries out the string-to-integer mapping to produce token IDs via the
# vocabulary.
#
# In addition, we implement a decode method that carries out the reverse
# integer-to-string mapping to convert the token IDs back into text.

# %% [markdown]
# Step 1: Store the vocabulary as a class attribute for access in the encode and decode methods
#
# Step 2: Create an inverse vocabulary that maps token IDs back to the original text tokens
#
# Step 3: Process input text into token IDs
#
# Step 4: Convert token IDs back into text
#
# Step 5: Replace spaces before the specified punctuation

# %%
class SimpleTokenizerV1:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = {i:s for s,i in vocab.items()}

    def encode(self, text):
        preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)

        preprocessed = [
            item.strip() for item in preprocessed if item.strip()
        ]
        ids = [self.str_to_int[s] for s in preprocessed]
        return ids

    def decode(self, ids):
        text = " ".join([self.int_to_str[i] for i in ids])
        # Replace spaces before the specified punctuations
        text = re.sub(r'\s+([,.?!"()\'])', r'\1', text)
        return text

# %%
# Out:
# 2ash
